# %%
import pandas as pd

# %%
a=  pd.DataFrame({"hindi":[45,78,58,89,56],"english":[75,78,89,85,98],"sankskrit":[78,55,89,45,35]})
print(a)
# Out:
#    hindi  english  sankskrit
# 0     45       75         78
# 1     78       78         55
# 2     58       89         89
# 3     89       85         45
# 4     56       98         35
#            hindi    english  sankskrit
# count   5.000000   5.000000   5.000000
# mean   65.200000  85.000000  60.400000
# std    17.852171   9.137833  22.578751
# min    45.000000  75.000000  35.000000
# 25%    56.000000  78.000000  45.000000
# 50%    58.000000  85.000000  55.000000
# 75%    78.000000  89.000000  78.000000
# max    89.000000  98.000000  89.000000

# %%
a.describe()
# Out:
#            hindi    english  sankskrit
# count   5.000000   5.000000   5.000000
# mean   65.200000  85.000000  60.400000
# std    17.852171   9.137833  22.578751
# min    45.000000  75.000000  35.000000
# 25%    56.000000  78.000000  45.000000
# 50%    58.000000  85.000000  55.000000
# 75%    78.000000  89.000000  78.000000
# max    89.000000  98.000000  89.000000

# %%
a=  pd.DataFrame({"hindi":[45,78,58,89,56],"english":[75,78,89,85,98],"sankskrit":[78,55,89,45,35]})
a.to_csv("sonu.csv")

# %%
a.to_csv("dabbie_index_false.csv", index = False)

# %%
b= a.head(10)
b
# Out:
#    hindi  english  sankskrit
# 0     45       75         78
# 1     78       78         55
# 2     58       89         89
# 3     89       85         45
# 4     56       98         35

# %%
a.shape
# Out:
# (5, 3)

# %%
z = a.loc[0]
z
# Out:
# hindi        45
# english      75
# sankskrit    78
# Name: 0, dtype: int64

# %%
x= a.iloc[0:2,0:1]
x
# Out:
#    hindi
# 0     45
# 1     78

# %%
z = pd.read_csv("heropanti.csv")
z
# Out:
#    hindi  english  sankskrit   city
# 0     45       75         78     mp
# 1     78       78         55     up
# 2     58       89         89     hp
# 3     89       85         45     ap
# 4     56       98         35  delhi
# 5     45       67         98     uk
# 6     58       78         76    goa

# %%
z =z["city"]
z
# Out:
# 0       mp
# 1       up
# 2       hp
# 3       ap
# 4    delhi
# 5       uk
# 6      goa
# Name: city, dtype: object

# %%
z = pd.read_csv("heropanti.csv")
b =z["english"][1]
b
# Out:
# 78

# %%
z = pd.read_csv("heropanti.csv")
z.index =['a','b','c','d','e','f','h']
print(z)
# Out:
#    hindi  english  sankskrit   city
# a     45       75         78     mp
# b     78       78         55     up
# c     58       89         89     hp
# d     89       85         45     ap
# e     56       98         35  delhi
# f     45       67         98     uk
# h     58       78         76    goa

# %%
import numpy as np
x = pd.Series(np.random.rand(44))
print(type(x))
# Out:
# <class 'pandas.core.series.Series'>

# %%
z = pd.DataFrame(np.random.rand(500,100),index =np.arange(500))
print(z)
x =z.head()
x
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.675861  0.224890  0.434398  0.397485  0.076207  0.267662  0.625025
# 1    0.728686  0.886539  0.972667  0.331011  0.772618  0.206352  0.036236
# 2    0.479794  0.535506  0.336578  0.837958  0.423508  0.724205  0.796765
# 3    0.638898  0.869372  0.964845  0.178835  0.390787  0.432418  0.803287
# 4    0.533508  0.815014  0.926971  0.095714  0.038631  0.584938  0.659204
# ..        ...       ...       ...       ...       ...       ...       ...
# 495  0.792949  0.508453  0.949109  0.928667  0.239631  0.163476  0.509159
# 496  0.234630  0.301906  0.769124  0.164305  0.384487  0.668778  0.965143
# 497  0.692471  0.372238  0.307660  0.929281  0.963631  0.094526  0.300838
# 498  0.110410  0.160168  0.074866  0.235839  0.402829  0.415613  0.784941
# 499  0.686131  0.069003  0.135144  0.660494  0.064374  0.883264  0.830213
#
#            7         8         9   ...        90        91        92  \
# ...

# %%
x.dtypes
# Out:
# 0     float64
# 1     float64
# 2     float64
# 3     float64
# 4     float64
#        ...
# 95    float64
# 96    float64
# 97    float64
# 98    float64
# 99    float64
# Length: 100, dtype: object

# %%
x[0][1] = "pihu"

x[1][2] = 8997
print(x)
# Out:
#          0            1         2         3         4         5         6   \
# 0  0.675861     0.224890  0.434398  0.397485  0.076207  0.267662  0.625025
# 1      pihu     0.886539  0.972667  0.331011  0.772618  0.206352  0.036236
# 2  0.479794  8997.000000  0.336578  0.837958  0.423508  0.724205  0.796765
# 3  0.638898     0.869372  0.964845  0.178835  0.390787  0.432418  0.803287
# 4  0.533508     0.815014  0.926971  0.095714  0.038631  0.584938  0.659204
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.110299  0.181265  0.025368  ...  0.168642  0.450525  0.437904  0.224112
# 1  0.748141  0.136707  0.004948  ...  0.110927  0.320650  0.578941  0.917605
# 2  0.745072  0.602594  0.626155  ...  0.509590  0.161658  0.315106  0.589323
# 3  0.190691  0.919514  0.795673  ...  0.282422  0.780561  0.911284  0.127184
# 4  0.329270  0.872651  0.948119  ...  0.802334  0.626670  0.001388  0.257501
#
# ...

# %%
# change to numpy array
c =x.to_numpy()
print(c)
# Out:
# [[0.6758606328195661 0.22488956134844285 0.4343978425014561
#   0.39748483720542604 0.07620668856904456 0.2676615193789299
#   0.625024836122366 0.11029860038193451 0.18126464478374638
#   0.025367704073422814 0.010439149288004379 0.2644066525793479
#   0.8689771686354307 0.15135251053678345 0.4205310640552169
#   0.7085129730305622 0.8806324270286564 0.49128840590067446
#   0.4478943034033105 0.20787257765143097 0.8768244855851919
#   0.7348089310753676 0.4257192634271195 0.5783955303457591
#   0.6501886339936783 0.43897013475695734 0.2093672425527543
#   0.43597031375056894 0.7329904937816842 0.11668702822122567
#   0.6809712679579705 0.3626463489613392 0.7541806508999092
#   0.12149950251126407 0.6993870885265532 0.084352944366344
#   0.8480858303246878 0.8144488883213293 0.419507704361204
#   0.2745135276154247 0.6645450213716888 0.8660769788449976
#   0.6587419947977232 0.9952872460685888 0.17766200420870948
#   0.7225287278485264 0.3164383903065707 0.3473229406513604
# ...

# %%
x.T
x
# Out:
#            0         1         2         3         4
# 0   0.675861      pihu  0.479794  0.638898  0.533508
# 1    0.22489  0.886539    8997.0  0.869372  0.815014
# 2   0.434398  0.972667  0.336578  0.964845  0.926971
# 3   0.397485  0.331011  0.837958  0.178835  0.095714
# 4   0.076207  0.772618  0.423508  0.390787  0.038631
# ..       ...       ...       ...       ...       ...
# 95  0.034824  0.258259  0.739547  0.769557   0.57736
# 96  0.592792  0.686058  0.364024  0.562112   0.15192
# 97   0.98706  0.657183  0.367958   0.39423  0.932063
# 98   0.64781  0.925661  0.259078  0.811479  0.150548
# 99  0.117841  0.639785  0.094881  0.812043  0.146619
#
# [100 rows x 5 columns]

# %%
x
# Out:
#          0            1         2         3         4         5         6   \
# 0  0.675861     0.224890  0.434398  0.397485  0.076207  0.267662  0.625025
# 1      pihu     0.886539  0.972667  0.331011  0.772618  0.206352  0.036236
# 2  0.479794  8997.000000  0.336578  0.837958  0.423508  0.724205  0.796765
# 3  0.638898     0.869372  0.964845  0.178835  0.390787  0.432418  0.803287
# 4  0.533508     0.815014  0.926971  0.095714  0.038631  0.584938  0.659204
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.110299  0.181265  0.025368  ...  0.168642  0.450525  0.437904  0.224112
# 1  0.748141  0.136707  0.004948  ...  0.110927  0.320650  0.578941  0.917605
# 2  0.745072  0.602594  0.626155  ...  0.509590  0.161658  0.315106  0.589323
# 3  0.190691  0.919514  0.795673  ...  0.282422  0.780561  0.911284  0.127184
# 4  0.329270  0.872651  0.948119  ...  0.802334  0.626670  0.001388  0.257501
#
# ...

# %%
x.index
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')

# %%
x.columns
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
# axis =0 for rows and axis  =1 is for columns;
x.sort_index(axis =0,ascending = False) # its sorting row  index by descending order,and by default index will be ascending order
# Out:
#          0            1         2         3         4         5         6   \
# 4  0.533508     0.815014  0.926971  0.095714  0.038631  0.584938  0.659204
# 3  0.638898     0.869372  0.964845  0.178835  0.390787  0.432418  0.803287
# 2  0.479794  8997.000000  0.336578  0.837958  0.423508  0.724205  0.796765
# 1      pihu     0.886539  0.972667  0.331011  0.772618  0.206352  0.036236
# 0  0.675861     0.224890  0.434398  0.397485  0.076207  0.267662  0.625025
#
#          7         8         9   ...        90        91        92        93  \
# 4  0.329270  0.872651  0.948119  ...  0.802334  0.626670  0.001388  0.257501
# 3  0.190691  0.919514  0.795673  ...  0.282422  0.780561  0.911284  0.127184
# 2  0.745072  0.602594  0.626155  ...  0.509590  0.161658  0.315106  0.589323
# 1  0.748141  0.136707  0.004948  ...  0.110927  0.320650  0.578941  0.917605
# 0  0.110299  0.181265  0.025368  ...  0.168642  0.450525  0.437904  0.224112
#
# ...

# %%
x.sort_index(axis =0,ascending = True)
# Out:
#          0            1         2         3         4         5         6   \
# 0  0.675861     0.224890  0.434398  0.397485  0.076207  0.267662  0.625025
# 1      pihu     0.886539  0.972667  0.331011  0.772618  0.206352  0.036236
# 2  0.479794  8997.000000  0.336578  0.837958  0.423508  0.724205  0.796765
# 3  0.638898     0.869372  0.964845  0.178835  0.390787  0.432418  0.803287
# 4  0.533508     0.815014  0.926971  0.095714  0.038631  0.584938  0.659204
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.110299  0.181265  0.025368  ...  0.168642  0.450525  0.437904  0.224112
# 1  0.748141  0.136707  0.004948  ...  0.110927  0.320650  0.578941  0.917605
# 2  0.745072  0.602594  0.626155  ...  0.509590  0.161658  0.315106  0.589323
# 3  0.190691  0.919514  0.795673  ...  0.282422  0.780561  0.911284  0.127184
# 4  0.329270  0.872651  0.948119  ...  0.802334  0.626670  0.001388  0.257501
#
# ...

# %%
x.sort_index(axis =1,ascending = False)
# Out:
#          99        98        97        96        95        94        93  \
# 0  0.117841  0.647810  0.987060  0.592792  0.034824  0.419678  0.224112
# 1  0.639785  0.925661  0.657183  0.686058  0.258259  0.468738  0.917605
# 2  0.094881  0.259078  0.367958  0.364024  0.739547  0.405760  0.589323
# 3  0.812043  0.811479  0.394230  0.562112  0.769557  0.420305  0.127184
# 4  0.146619  0.150548  0.932063  0.151920  0.577360  0.552146  0.257501
#
#          92        91        90  ...        9         8         7         6   \
# 0  0.437904  0.450525  0.168642  ...  0.025368  0.181265  0.110299  0.625025
# 1  0.578941  0.320650  0.110927  ...  0.004948  0.136707  0.748141  0.036236
# 2  0.315106  0.161658  0.509590  ...  0.626155  0.602594  0.745072  0.796765
# 3  0.911284  0.780561  0.282422  ...  0.795673  0.919514  0.190691  0.803287
# 4  0.001388  0.626670  0.802334  ...  0.948119  0.872651  0.329270  0.659204
#
#          5         4         3         2            1         0
# ...

# %%
x[0]
# Out:
# 0    0.675861
# 1        pihu
# 2    0.479794
# 3    0.638898
# 4    0.533508
# Name: 0, dtype: object

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 100 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       5 non-null      object
#  1   1       5 non-null      float64
#  2   2       5 non-null      float64
#  3   3       5 non-null      float64
#  4   4       5 non-null      float64
#  5   5       5 non-null      float64
#  6   6       5 non-null      float64
#  7   7       5 non-null      float64
#  8   8       5 non-null      float64
#  9   9       5 non-null      float64
#  10  10      5 non-null      float64
#  11  11      5 non-null      float64
#  12  12      5 non-null      float64
#  13  13      5 non-null      float64
#  14  14      5 non-null      float64
#  15  15      5 non-null      float64
#  16  16      5 non-null      float64
#  17  17      5 non-null      float64
#  18  18      5 non-null      float64
#  19  19      5 non-null      float64
#  20  20      5 non-null      float64
# ...
