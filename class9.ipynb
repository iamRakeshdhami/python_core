# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
#      -------------------------------------- 242.1/242.1 KB 7.2 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.3; however, version 22.1.1 is available.
# You should consider upgrading via the 'C:\Users\acer\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
x =pd.read_excel("C:/Users/acer/OneDrive/Documents/sonu.xlsx")
print(x)
# Out:
#                                        State  Confirmed  Active  Recovered  \
# 0                Andaman and Nicobar Islands      10039       3       9907
# 1                             Andhra Pradesh    2319797      72    2304995
# 2                          Arunachal Pradesh      64503       4      64203
# 3                                      Assam     724220       2     716232
# 4                                      Bihar     830653      49     818348
# 5                                 Chandigarh      92208      84      90959
# 6                               Chhattisgarh    1152333      28    1138271
# 7   Dadra and Nagar Haveli and Daman and Diu      11441       0      11437
# 8                                      Delhi    1899072    4341    1868543
# 9                                        Goa     245548      67     241649
# 10                                   Gujarat    1224657     211    1213502
# ...

# %%
x =pd.read_excel("C:/Users/acer/OneDrive/Documents/sonu.xlsx")
x.iloc[0,2]=500
x
# Out:
#    Unnamed: 0.1  Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0             0         600        500      marks
# 1             1           1       sonu         45
# 2             2           2     pankaj         55
# 3             3           3     rakesh         65
# 4             4           4       muna         75
# 5             5           5   narendra         85
# 6             6           6      rahul         64

# %%
x =pd.read_excel("C:/Users/acer/OneDrive/Documents/sonu.xlsx",sheet_name ="Sheet1")
x
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0    roll no       name      marks
# 1          1       sonu         45
# 2          2     pankaj         55
# 3          3     rakesh         65
# 4          4       muna         75
# 5          5   narendra         85
# 6          6      rahul         64

# %%
x =pd.read_excel("C:/Users/acer/OneDrive/Documents/sonu.xlsx",sheet_name ="Sheet2")
x
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0         NaN       name     sports      state
# 1         NaN       sonu      chess         uk
# 2         NaN     dabbie  badminton         up
# 3         NaN         pk   football         hm
# 4         NaN     sambha   baseball         ap
# 5         NaN     gabbar   shooting     ramgad
# 6         NaN     rancho      poker         mp

# %%
x =pd.read_excel("C:/Users/acer/OneDrive/Documents/sonu.xlsx",sheet_name =["Sheet2","Sheet1"])
x
# Out:
# {'Sheet2':    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3
#  0         NaN       name     sports      state
#  1         NaN       sonu      chess         uk
#  2         NaN     dabbie  badminton         up
#  3         NaN         pk   football         hm
#  4         NaN     sambha   baseball         ap
#  5         NaN     gabbar   shooting     ramgad
#  6         NaN     rancho      poker         mp,
#  'Sheet1':   Unnamed: 0 Unnamed: 1 Unnamed: 2
#  0    roll no       name      marks
#  1          1       sonu         45
#  2          2     pankaj         55
#  3          3     rakesh         65
#  4          4       muna         75
#  5          5   narendra         85
#  6          6      rahul         64}

# %%
x =pd.read_excel("C:/Users/acer/OneDrive/Documents/sonu.xlsx",sheet_name ="Sheet1")
x.iloc[1:1]=600
x
# Out:
#    Unnamed: 0.1  Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0             0         600       name      marks
# 1             1           1       sonu         45
# 2             2           2     pankaj         55
# 3             3           3     rakesh         65
# 4             4           4       muna         75
# 5             5           5   narendra         85
# 6             6           6      rahul         64

# %%
x
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0        600       name      marks
# 1          1        600         45
# 2          2     pankaj         55
# 3          3     rakesh         65
# 4          4       muna         75
# 5          5   narendra         85
# 6          6      rahul         64

# %%
a=pd.read_excel("C:/Users/acer/OneDrive/Documents/gabbar.xlsx",sheet_name =["Sheet1","Sheet2","covid"])
a
# Out:
# {'Sheet1':   Unnamed: 0 Unnamed: 1 Unnamed: 2
#  0    roll no       name      marks
#  1          1       sonu         45
#  2          2     pankaj         55
#  3          3     rakesh         65
#  4          4       muna         75
#  5          5   narendra         85
#  6          6      rahul         64,
#  'Sheet2':    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3
#  0         NaN       name     sports      state
#  1         NaN       sonu      chess         uk
#  2         NaN     dabbie  badminton         up
#  3         NaN         pk   football         hm
#  4         NaN     sambha   baseball         ap
#  5         NaN     gabbar   shooting     ramgad
#  6         NaN     rancho      poker         mp,
#  'covid':                                        State  Confirmed  Active  Recovered  \
#  0                Andaman and Nicobar Islands      10039       3       9907
#  1                             Andhra Pradesh    2319797      72    2304995
# ...

# %%
a =a.copy()
with pd.ExcelWriter('input.xlsx')as writer:
    x.to_excel(writer,sheet_name="Sheet1")
    y.to_excel(writer,sheet_name="Sheet2")

# %%
a=pd.read_excel("C:/Users/acer/OneDrive/Documents/gabbar.xlsx",sheet_name =["Sheet1","Sheet2","covid"])
a
# Out:
#    Unnamed: 0.1  Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0             0         600       name      marks
# 1             1           1       sonu         45
# 2             2           2     pankaj         55
# 3             3           3     rakesh         65
# 4             4           4       muna         75
# 5             5           5   narendra         85
# 6             6           6      rahul         64

# %%
y
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 1, Unnamed: 2, Unnamed: 3]
# Index: []
